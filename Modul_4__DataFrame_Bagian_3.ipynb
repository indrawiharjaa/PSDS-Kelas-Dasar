# %% [markdown]
# <a href="https://colab.research.google.com/github/indracahyaramdani/PSDS/blob/main/Modul_4__DataFrame_Bagian_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![PSDS MODUL 1.png](data:image/png;base64,...)

# %% [markdown]
# Assalamualaikum warahmatullahi wabarakatuh.
#
# Robbi Zidni Ilma Warzuqni Fahma
#
# Semoga Allah memberi kemudahan untuk kita memperoleh ilmu yang bermanfaat.
#
# Ini adalah notebook yang disusun untuk program **Pejuang Data Sains 1.0**
#
# ---
#
# Ini adalah Modul: **Pandas DataFrame Bagian-3
# (Modification DataFrame)**
#
#
# ---
#
# **Sebelum memulai mempelajari notebook ini, jangan lupa untuk menyalinnya di drive masing-masing ya.**
#
# **!!!**

# %% [markdown]
# #Modification DataFrame

# %% [markdown]
# ##Merubah Nama Kolom

# %%
# Membuat DataFrame

import pandas as pd
data = {'satu' : [1,1,1,1],'dua' : [2,2,2,2],'tiga' : [3,3,3,3]}

df = pd.DataFrame(data, columns=['satu','dua','tiga'])
df = pd.DataFrame(data,index=['a','b','c','d'])

df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %%
#Silahkan coba sendiri
#Membuat Data Frame

import pandas as pd
data = {'satu' : [1,1,1,1], 'dua' : [2,2,2,2], 'tiga' : [3,3,3,3]}

df = pd.DataFrame(data, columns = ['satu','dua','tiga'])
df = pd.DataFrame(data, index = ['a','b','c','d'])

df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %%
# Merubah Nama Kolom
df.columns =['pertama','kedua','ketiga']
df
# Out:
#    pertama  kedua  ketiga
# a        1      2       3
# b        1      2       3
# c        1      2       3
# d        1      2       3

# %%
#Saatnya kamu mencoba disini
#Mengubah nama kolom

df.columns = ['pertama','kedua','ketiga']
df
# Out:
#    pertama  kedua  ketiga
# a        1      2       3
# b        1      2       3
# c        1      2       3
# d        1      2       3

# %% [markdown]
# ##Menambah Kolom baru berdasarkan data yang ada

# %%
#Membuat DataFrame
import pandas as pd
data = {'satu' : [1,1,1,1],'dua' : [2,2,2,2],'tiga' : [3,3,3,3]}

df = pd.DataFrame(data, columns=['satu','dua','tiga'])
df = pd.DataFrame(data,index=['a','b','c','d'])

df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %%
#Menambah Kolom baru berdasarkan data yang ada, misal kolom D=Kolom C^2
df['keempat']=df['ketiga']**2
df
# Out:
#    pertama  kedua  ketiga  keempat
# a        1      2       3        9
# b        1      2       3        9
# c        1      2       3        9
# d        1      2       3        9

# %% [markdown]
# ##Menambah Kolom baru dengan list data baru

# %%
#Menambah Kolom baru dengan list data baru

df['kelima']=pd.DataFrame([5,5,5,5],index=['a','b','c','d'])
df
# Out:
#    pertama  kedua  ketiga  keempat  kelima
# a        1      2       3        9       5
# b        1      2       3        9       5
# c        1      2       3        9       5
# d        1      2       3        9       5

# %%
#Saatnya kamu mencoba disini

# %% [markdown]
# ##Menghapus baris yang berisi 0, NaN, empty

# %%
#Membuat DataFrame
import pandas as pd


data = {'satu' : [1,np.nan,1,1],'dua' : [2,2,np.nan,2],'tiga' : [3,3,3,3]}

df = pd.DataFrame(data, columns=['satu','dua','tiga'])
df = pd.DataFrame(data, index=['a','b','c','d'])

df
# Out:
#    satu  dua  tiga
# a   1.0  2.0     3
# b   NaN  2.0     3
# c   1.0  NaN     3
# d   1.0  2.0     3

# %%
#Menghapus baris yang berisi NaN
df.dropna(axis=1) #bisa ditulis juga df.dropna(axis=0). akan menghapus semua baris yang memiliki NaN. atau df.dropna(axis=1), menghapus semua kolom yang memiliki NaN
# Out:
#    tiga
# a     3
# b     3
# c     3
# d     3

# %%
#Saatnya kamu mencoba disini

# %% [markdown]
# ##Membuat dataframe baru dengan memilih kolom tertentu(column Slicing)

# %%
import pandas as pd
data = {'satu' : [1,1,1,1],'dua' : [2,2,2,2],'tiga' : [3,3,3,3]}

df = pd.DataFrame(data, columns=['satu','dua','tiga'])
df = pd.DataFrame(data, index=['a','b','c','d'])

df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %%
df['tiga']
# Out:
# a    3
# b    3
# c    3
# d    3
# Name: tiga, dtype: int64

# %%
#Saatnya kamu mencoba disini
df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %% [markdown]
# ##Membuat dataframe baru dengan memilih baris tertentu(row Slicing)

# %%
#Membuat DataFrame
import pandas as pd
data = {'satu' : [1,1,1,1],'dua' : [2,2,2,2],'tiga' : [3,3,3,3]}

df = pd.DataFrame(data, columns=['satu','dua','tiga'])
df = pd.DataFrame(data, index=['a','b','c','d'])

df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %%
#Membuat dataframe baru dengan memilih baris tertentu(row Slicing)
df[2:3]
# Out:
#    satu  dua  tiga
# c     1    2     3

# %%
#Saatnya kamu mencoba disini
df
# Out:
#    satu  dua  tiga
# a     1    2     3
# b     1    2     3
# c     1    2     3
# d     1    2     3

# %% [markdown]
# ##Membuat dataframe baru dengan slicing dengan iloc

# %%
#iloc function
data = {'Nama' : ['Budi','Adi','Putri','Diah'],'Umur' : [17,25,24,30],'Gender' : ['L','L','P','P'], 'Pekerjaan':['Pelajar','Dokter','PNS','Ibu Rumah Tangga']}

df = pd.DataFrame(data, columns=['Nama','Umur','Gender','Pekerjaan'])
df = pd.DataFrame(data, index=['a','b','c','d'])

df
# Out:
#     Nama  Umur Gender         Pekerjaan
# a   Budi    17      L           Pelajar
# b    Adi    25      L            Dokter
# c  Putri    24      P               PNS
# d   Diah    30      P  Ibu Rumah Tangga

# %%
df
# Out:
#     Nama  Umur Gender         Pekerjaan
# a   Budi    17      L           Pelajar
# b    Adi    25      L            Dokter
# c  Putri    24      P               PNS
# d   Diah    30      P  Ibu Rumah Tangga

# %%
df.iloc[:]
# Out:
#     Nama  Umur Gender         Pekerjaan
# a   Budi    17      L           Pelajar
# b    Adi    25      L            Dokter
# c  Putri    24      P               PNS
# d   Diah    30      P  Ibu Rumah Tangga

# %%
df.iloc[1,3]
# Out:
# 'Dokter'

# %%
df.iloc[1:3,1:-1]
# Out:
#    Umur Gender
# b    25      L
# c    24      P

# %%
df.iloc[1:3,1:-1].values
# Out:
# array([[25, 'L'],
#        [24, 'P']], dtype=object)
